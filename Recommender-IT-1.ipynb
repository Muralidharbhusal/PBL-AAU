# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("movies.csv")
data.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
links=pd.read_csv('links.csv')
links.head(10)
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0
# 5        6  113277    949.0
# 6        7  114319  11860.0
# 7        8  112302  45325.0
# 8        9  114576   9091.0
# 9       10  113189    710.0

# %%
ratings=pd.read_csv('ratings.csv')
ratings.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
tags=pd.read_csv('tags.csv')
tags.head(10)
# Out:
#    userId  movieId                tag   timestamp
# 0       2    60756              funny  1445714994
# 1       2    60756    Highly quotable  1445714996
# 2       2    60756       will ferrell  1445714992
# 3       2    89774       Boxing story  1445715207
# 4       2    89774                MMA  1445715200
# 5       2    89774          Tom Hardy  1445715205
# 6       2   106782              drugs  1445715054
# 7       2   106782  Leonardo DiCaprio  1445715051
# 8       2   106782    Martin Scorsese  1445715056
# 9       7    48516       way too long  1169687325

# %%
data.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
links.isnull().sum()
# Out:
# movieId    0
# imdbId     0
# tmdbId     8
# dtype: int64

# %%
tags.isnull().sum()
# Out:
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
ratings = ratings.drop(['userId'], axis = 1)
ratings
# Out:
#         movieId  rating   timestamp
# 0             1     4.0   964982703
# 1             3     4.0   964981247
# 2             6     4.0   964982224
# 3            47     5.0   964983815
# 4            50     5.0   964982931
# ...         ...     ...         ...
# 100831   166534     4.0  1493848402
# 100832   168248     5.0  1493850091
# 100833   168250     5.0  1494273047
# 100834   168252     5.0  1493846352
# 100835   170875     3.0  1493846415
#
# [100836 rows x 3 columns]

# %%
tags = tags.drop(['userId'], axis = 1)
tags
# Out:
#       movieId               tag   timestamp
# 0       60756             funny  1445714994
# 1       60756   Highly quotable  1445714996
# 2       60756      will ferrell  1445714992
# 3       89774      Boxing story  1445715207
# 4       89774               MMA  1445715200
# ...       ...               ...         ...
# 3678     7382         for katie  1171234019
# 3679     7936           austere  1173392334
# 3680     3265            gun fu  1493843984
# 3681     3265  heroic bloodshed  1493843978
# 3682   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 3 columns]

# %%
movies = data.merge(links, on = "movieId")
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres   imdbId    tmdbId
# 0     Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1                      Adventure|Children|Fantasy   113497    8844.0
# 2                                  Comedy|Romance   113228   15602.0
# ...

# %%
movies = movies.merge(ratings, on = "movieId")
movies
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...

# %%
movies = movies.merge(tags, on = "movieId")
movies
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 2       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 3       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...

# %%
movies = movies.merge(data, on = "movieId")
movies
# Out:
#         movieId                         title_x  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                            genres_x   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 2       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 3       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...

# %%
movies = movies.drop(['title_x','genres_y','timestamp_x','timestamp_y'], axis =1)
movies
# Out:
#         movieId                                     genres_x   imdbId  \
# 0             1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 1             1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 2             1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 3             1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 4             1  Adventure|Animation|Children|Comedy|Fantasy   114709
# ...         ...                                          ...      ...
# 233208   187595             Action|Adventure|Children|Sci-Fi  3778644
# 233209   193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233210   193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233211   193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233212   193565               Action|Animation|Comedy|Sci-Fi  1636780
#
#           tmdbId  rating        tag                         title_y
# ...

# %%
movies = movies.rename(columns={'movieId':'id', 'genre_x':'genre', 'title_y':'title'})
movies
# Out:
#             id                                     genres_x   imdbId  \
# 0            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 1            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 2            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 3            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 4            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# ...        ...                                          ...      ...
# 233208  187595             Action|Adventure|Children|Sci-Fi  3778644
# 233209  193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233210  193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233211  193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233212  193565               Action|Animation|Comedy|Sci-Fi  1636780
#
#           tmdbId  rating        tag                           title
# 0          862.0     4.0      pixar                Toy Story (1995)
# ...

# %%
movies = movies.rename(columns={'movieId':'id', 'genres_x':'genre', 'title_y':'title'})
movies
# Out:
#             id                                        genre   imdbId  \
# 0            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 1            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 2            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 3            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# 4            1  Adventure|Animation|Children|Comedy|Fantasy   114709
# ...        ...                                          ...      ...
# 233208  187595             Action|Adventure|Children|Sci-Fi  3778644
# 233209  193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233210  193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233211  193565               Action|Animation|Comedy|Sci-Fi  1636780
# 233212  193565               Action|Animation|Comedy|Sci-Fi  1636780
#
#           tmdbId  rating        tag                           title
# 0          862.0     4.0      pixar                Toy Story (1995)
# ...

# %%
movies_df = movies[['id','genre','rating','tag','title']]
movies_df
# Out:
#             id                                        genre  rating  \
# 0            1  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 1            1  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 2            1  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 3            1  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 4            1  Adventure|Animation|Children|Comedy|Fantasy     4.0
# ...        ...                                          ...     ...
# 233208  187595             Action|Adventure|Children|Sci-Fi     5.0
# 233209  193565               Action|Animation|Comedy|Sci-Fi     3.5
# 233210  193565               Action|Animation|Comedy|Sci-Fi     3.5
# 233211  193565               Action|Animation|Comedy|Sci-Fi     3.5
# 233212  193565               Action|Animation|Comedy|Sci-Fi     3.5
#
#               tag                           title
# 0           pixar                Toy Story (1995)
# ...

# %%
movies_df.duplicated()
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 233208    False
# 233209    False
# 233210    False
# 233211    False
# 233212    False
# Length: 233213, dtype: bool

# %%
movies_df.duplicated().sum()
# Out:
# 210954

# %%
movies_df.head(20)
# Out:
#     id                                        genre  rating    tag  \
# 0    1  Adventure|Animation|Children|Comedy|Fantasy     4.0  pixar
# 1    1  Adventure|Animation|Children|Comedy|Fantasy     4.0  pixar
# 2    1  Adventure|Animation|Children|Comedy|Fantasy     4.0    fun
# 3    1  Adventure|Animation|Children|Comedy|Fantasy     4.0  pixar
# 4    1  Adventure|Animation|Children|Comedy|Fantasy     4.0  pixar
# 5    1  Adventure|Animation|Children|Comedy|Fantasy     4.0    fun
# 6    1  Adventure|Animation|Children|Comedy|Fantasy     4.5  pixar
# 7    1  Adventure|Animation|Children|Comedy|Fantasy     4.5  pixar
# 8    1  Adventure|Animation|Children|Comedy|Fantasy     4.5    fun
# 9    1  Adventure|Animation|Children|Comedy|Fantasy     2.5  pixar
# 10   1  Adventure|Animation|Children|Comedy|Fantasy     2.5  pixar
# 11   1  Adventure|Animation|Children|Comedy|Fantasy     2.5    fun
# 12   1  Adventure|Animation|Children|Comedy|Fantasy     4.5  pixar
# ...

# %%
movies_df = movies_df.drop_duplicates()
movies_df
# Out:
#             id                                        genre  rating  \
# 0            1  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 2            1  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 6            1  Adventure|Animation|Children|Comedy|Fantasy     4.5
# 8            1  Adventure|Animation|Children|Comedy|Fantasy     4.5
# 9            1  Adventure|Animation|Children|Comedy|Fantasy     2.5
# ...        ...                                          ...     ...
# 233208  187595             Action|Adventure|Children|Sci-Fi     5.0
# 233209  193565               Action|Animation|Comedy|Sci-Fi     3.5
# 233210  193565               Action|Animation|Comedy|Sci-Fi     3.5
# 233211  193565               Action|Animation|Comedy|Sci-Fi     3.5
# 233212  193565               Action|Animation|Comedy|Sci-Fi     3.5
#
#               tag                           title
# 0           pixar                Toy Story (1995)
# ...

# %%
data.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9737    False
# 9738    False
# 9739    False
# 9740    False
# 9741    False
# Length: 9742, dtype: bool

# %%
data.shape
# Out:
# (9742, 3)

# %%
links.shape
# Out:
# (9742, 3)

# %%
links.duplicated().sum()
# Out:
# 0

# %%
movies_df.duplicated().sum()
# Out:
# 0

# %%
movies_df.duplicated()
# Out:
# 0         False
# 2         False
# 6         False
# 8         False
# 9         False
#           ...
# 233208    False
# 233209    False
# 233210    False
# 233211    False
# 233212    False
# Length: 22259, dtype: bool
